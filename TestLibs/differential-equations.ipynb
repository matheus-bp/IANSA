# %%
using Pkg
Pkg.add("DifferentialEquations")
# Out:
#    Resolving package versions...
#    Installed MaybeInplace ────────────── v0.1.3
#    Installed Polyester ───────────────── v0.7.15
#    Installed TriangularSolve ─────────── v0.2.1
#    Installed Accessors ───────────────── v0.1.37
#    Installed Sundials_jll ────────────── v5.2.2+0
#    Installed RecursiveArrayTools ─────── v3.26.0
#    Installed NonlinearSolve ──────────── v3.13.1
#    Installed SteadyStateDiffEq ───────── v2.3.0
#    Installed DifferentialEquations ───── v7.13.0
#    Installed Static ──────────────────── v1.1.1
#    Installed MuladdMacro ─────────────── v0.2.4
#    Installed FiniteDiff ──────────────── v2.23.1
#    Installed ArnoldiMethod ───────────── v0.4.0
#    Installed BoundaryValueDiffEq ─────── v5.9.0
#    Installed Functors ────────────────── v0.4.12
#    Installed SciMLBase ───────────────── v2.48.1
#    Installed BandedMatrices ──────────── v1.7.2
#    Installed DiffEqBase ──────────────── v6.152.2
#    Installed CpuId ───────────────────── v0.3.1
# ...

# %%
import DifferentialEquations
dfe = DifferentialEquations

# %%
f(u, p, t) = 1.01 * u
u0 = 1 / 2
tspan = (0.0, 1.0)
prob = dfe.ODEProblem(f, u0, tspan)
